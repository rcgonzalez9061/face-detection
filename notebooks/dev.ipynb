# %%
import os
import sys

os.chdir('/home/roobz/Jupyter/face-detection')

from src import plot
from src import utils

# %load_ext autoreload
# %autoreload 2

# %%
plotter = plot.Plotter()

# %%
plotter.plot_baseline('0--Parade/0_Parade_marchingband_1_1015.jpg', True, True)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x7FAB6049CD30>

# %%
plotter.plot_baseline('58--Hockey/58_Hockey_icehockey_puck_58_960.jpg', True)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x680 at 0x7FAB4820CB50>
